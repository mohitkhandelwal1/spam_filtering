# %%
# !pip install pgmpy==0.1.23
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pgmpy==0.1.23 in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.1.23)
# Requirement already satisfied: networkx in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pgmpy==0.1.23) (3.4.2)
# Requirement already satisfied: numpy in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pgmpy==0.1.23) (2.1.2)
# Requirement already satisfied: scipy in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pgmpy==0.1.23) (1.14.1)
# Requirement already satisfied: scikit-learn in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pgmpy==0.1.23) (1.5.2)
# Requirement already satisfied: pandas in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pgmpy==0.1.23) (2.2.3)
# Requirement already satisfied: pyparsing in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pgmpy==0.1.23) (3.2.0)
# Requirement already satisfied: torch in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pgmpy==0.1.23) (2.5.0)
# Requirement already satisfied: statsmodels in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pgmpy==0.1.23) (0.14.4)
# Requirement already satisfied: tqdm in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pgmpy==0.1.23) (4.66.5)
# Requirement already satisfied: joblib in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pgmpy==0.1.23) (1.4.2)
# Requirement already satisfied: opt-einsum in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pgmpy==0.1.23) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->pgmpy==0.1.23) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->pgmpy==0.1.23) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->pgmpy==0.1.23) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn->pgmpy==0.1.23) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from statsmodels->pgmpy==0.1.23) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from statsmodels->pgmpy==0.1.23) (24.1)
# Requirement already satisfied: filelock in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch->pgmpy==0.1.23) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch->pgmpy==0.1.23) (4.12.2)
# Requirement already satisfied: jinja2 in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch->pgmpy==0.1.23) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch->pgmpy==0.1.23) (2024.10.0)
# Requirement already satisfied: setuptools in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch->pgmpy==0.1.23) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch->pgmpy==0.1.23) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sympy==1.13.1->torch->pgmpy==0.1.23) (1.3.0)
# Requirement already satisfied: colorama in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm->pgmpy==0.1.23) (0.4.6)
# Requirement already satisfied: six in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from patsy>=0.5.6->statsmodels->pgmpy==0.1.23) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\student\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jinja2->torch->pgmpy==0.1.23) (3.0.2)

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator

# Step 1: Load and clean the data
data = pd.read_csv("spam.csv", encoding='latin-1')
cleaned_data = data[['v1', 'v2']].rename(columns={'v1': 'label', 'v2': 'message'})
cleaned_data['label'] = cleaned_data['label'].map({'ham': 0, 'spam': 1})

# Step 2: Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    cleaned_data['message'], cleaned_data['label'], test_size=0.2, random_state=42
)

# Step 3: Vectorize text data using TF-IDF
vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Step 4: Convert TF-IDF features to binary (presence/absence of words)
X_train_binary = (X_train_tfidf > 0).astype(int).toarray()
X_test_binary = (X_test_tfidf > 0).astype(int).toarray()

# Step 5: Create a Bayesian Network model
nodes = [f'word_{i}' for i in range(X_train_binary.shape[1])]
nodes.insert(0, 'label')  # Add 'label' node

# Define edges where the label influences all word nodes
edges = [('label', f'word_{i}') for i in range(1000)]
model = BayesianNetwork(edges)

# Step 6: Prepare the training data as a DataFrame
train_data_df = pd.DataFrame(X_train_binary, columns=nodes[1:])
train_data_df['label'] = y_train.values

# Train the model using Maximum Likelihood Estimation
model.fit(train_data_df, estimator=MaximumLikelihoodEstimator)

# Step 7: Make predictions on the test data
test_data_df = pd.DataFrame(X_test_binary, columns=nodes[1:])
y_pred = model.predict(test_data_df)['label']

# Step 8: Evaluate the model
report = classification_report(y_test, y_pred, target_names=['Ham', 'Spam'])
print(report)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Import necessary libraries
# ----> 2 import pandas as pd
#       3 import numpy as np
#       4 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'pandas'
